# %% [markdown]
# # Data Exploration
#
# This notebook explores the bus and transmission line data used for power system load flow analysis.
#
# Objectives:
#
# - Load bus data
# - Load line data
# - Inspect network structure
# - Verify data quality

# %%
import pandas as pd

bus_data = pd.read_csv("../data/sample_bus_data.csv")
line_data = pd.read_csv("../data/sample_line_data.csv")

print("Bus Data")
display(bus_data)

print("Line Data")
display(line_data)

# %%
print("Number of Buses:", len(bus_data))
print("Number of Transmission Lines:", len(line_data))

# %%
print(bus_data.info())

# %% [markdown]
# ## Observations
#
# The system consists of:
#
# - 1 Slack Bus
# - 1 PV Bus
# - Multiple PQ Buses
#
# The transmission network is interconnected and suitable for load flow studies.
